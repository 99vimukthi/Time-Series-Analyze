# %%
import pandas as pd

# %%
df=pd.read_csv('AllDistrict_Production_OutliersRemove.csv')

# %%
df.head()
# Out:
#       Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 0  1/1/2016      3102903.0             0.0               0           219.0
# 1  2/1/2016      2822829.0             8.0               2           201.5
# 2  3/1/2016      1990515.0             0.0               0           244.4
# 3  4/1/2016      2847736.0            41.0               5           233.9
# 4  5/1/2016      3209612.0           187.5              15           118.8
#
#    Fertilizer  District
# 0      160.65         1
# 1      231.25         1
# 2      489.70         1
# 3      255.30         1
# 4      768.13         1

# %%
df.tail()
# Out:
#          Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 306   8/1/2022      3003573.0           184.4              14          181.99
# 307   9/1/2022      2957228.0            74.6              15          181.99
# 308  10/1/2022      2737942.0           749.9              25          181.99
# 309  11/1/2022      3213092.0           162.3              14          181.99
# 310  12/1/2022      2986014.0           190.4              13          181.99
#
#      Fertilizer  District
# 306     1463.90         4
# 307     1325.81         4
# 308     1581.84         4
# 309     1557.84         4
# 310     2200.69         4

# %%
df.shape
# Out:
# (311, 7)

# %%
import numpy as np

# %%
data_train=df.sample(frac=0.9,random_state=786)

# %%
data_train.shape
# Out:
# (280, 7)

# %%
data_train.head()
# Out:
#          Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 230   9/1/2022      4071957.0            71.0              13          153.40
# 82    1/1/2016      6114284.0           139.7               7          188.80
# 142   1/1/2022      4897273.0           204.2              13          237.00
# 45   11/1/2019      2425851.0           222.1              11          195.68
# 39    4/1/2019      2812379.0           125.3               7          178.50
#
#      Fertilizer  District
# 230      416.26         3
# 82       392.90         2
# 142     1030.99         2
# 45      1446.79         1
# 39      1446.79         1

# %%
data_test=df.drop(data_train.index)

# %%
data_test.shape
# Out:
# (31, 7)

# %%
data_test.head()
# Out:
#         Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 5    6/1/2016      3258617.0            68.0              12          172.80
# 20   9/1/2017      3510599.0           175.7              14          195.68
# 46  12/1/2019      2881389.0            84.9               7          195.68
# 48   2/1/2020      1592016.0             0.0               0          233.80
# 52   6/1/2020      2767460.0            92.6              10          205.00
#
#     Fertilizer  District
# 5       682.30         1
# 20     2023.82         1
# 46     1446.79         1
# 48      860.32         1
# 52     3606.54         1

# %%
data_train.reset_index(drop=True,inplace=True)

# %%
data_train.head()
# Out:
#        Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 0   9/1/2022      4071957.0            71.0              13          153.40
# 1   1/1/2016      6114284.0           139.7               7          188.80
# 2   1/1/2022      4897273.0           204.2              13          237.00
# 3  11/1/2019      2425851.0           222.1              11          195.68
# 4   4/1/2019      2812379.0           125.3               7          178.50
#
#    Fertilizer  District
# 0      416.26         3
# 1      392.90         2
# 2     1030.99         2
# 3     1446.79         1
# 4     1446.79         1

# %%
data_test.reset_index(drop=True,inplace=True)

# %%
data_test.head()
# Out:
#        Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 0   6/1/2016      3258617.0            68.0              12          172.80
# 1   9/1/2017      3510599.0           175.7              14          195.68
# 2  12/1/2019      2881389.0            84.9               7          195.68
# 3   2/1/2020      1592016.0             0.0               0          233.80
# 4   6/1/2020      2767460.0            92.6              10          205.00
#
#    Fertilizer  District
# 0      682.30         1
# 1     2023.82         1
# 2     1446.79         1
# 3      860.32         1
# 4     3606.54         1

# %%
from pycaret.regression import *

# %%
reg=setup(data=data_train,target="Production/kg",session_id=123)
# Out:
# <style type="text/css">
# #T_78ab2_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_78ab2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78ab2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_78ab2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78ab2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78ab2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_78ab2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78ab2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_78ab2_row1_col1" class="data row1 col1" >Production/kg</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78ab2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_78ab2_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78ab2_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_78ab2_row3_col1" class="data row3 col1" >(280, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_78ab2_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_78ab2_row4_col1" class="data row4 col1" >(280, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_78ab2_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_78ab2_row5_col1" class="data row5 col1" >(196, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_78ab2_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_78ab2_row6_col1" class="data row6 col1" >(84, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_78ab2_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_78ab2_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_78ab2_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_78ab2_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_78ab2_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_78ab2_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_78ab2_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_78ab2_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_78ab2_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_78ab2_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_78ab2_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_78ab2_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_78ab2_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_78ab2_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_78ab2_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_78ab2_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_78ab2_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_78ab2_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_78ab2_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_78ab2_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_78ab2_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_78ab2_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_78ab2_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_78ab2_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_78ab2_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_78ab2_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_78ab2_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_78ab2_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_78ab2_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_78ab2_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_78ab2_row21_col1" class="data row21 col1" >60a0</td>
#     </tr>
#   </tbody>
# </table>

# %%
best=compare_models(exclude=["ransac"])
# Out:
# <style type="text/css">
# #T_db9f1 th {
#   text-align: left;
# }
# #T_db9f1_row0_col0, #T_db9f1_row0_col6, #T_db9f1_row1_col0, #T_db9f1_row1_col1, #T_db9f1_row1_col2, #T_db9f1_row1_col3, #T_db9f1_row1_col4, #T_db9f1_row1_col5, #T_db9f1_row1_col6, #T_db9f1_row2_col0, #T_db9f1_row2_col1, #T_db9f1_row2_col2, #T_db9f1_row2_col3, #T_db9f1_row2_col4, #T_db9f1_row2_col5, #T_db9f1_row3_col0, #T_db9f1_row3_col1, #T_db9f1_row3_col2, #T_db9f1_row3_col3, #T_db9f1_row3_col4, #T_db9f1_row3_col5, #T_db9f1_row3_col6, #T_db9f1_row4_col0, #T_db9f1_row4_col1, #T_db9f1_row4_col2, #T_db9f1_row4_col3, #T_db9f1_row4_col4, #T_db9f1_row4_col5, #T_db9f1_row4_col6, #T_db9f1_row5_col0, #T_db9f1_row5_col1, #T_db9f1_row5_col2, #T_db9f1_row5_col3, #T_db9f1_row5_col4, #T_db9f1_row5_col5, #T_db9f1_row5_col6, #T_db9f1_row6_col0, #T_db9f1_row6_col1, #T_db9f1_row6_col2, #T_db9f1_row6_col3, #T_db9f1_row6_col4, #T_db9f1_row6_col5, #T_db9f1_row6_col6, #T_db9f1_row7_col0, #T_db9f1_row7_col1, #T_db9f1_row7_col2, #T_db9f1_row7_col3, #T_db9f1_row7_col4, #T_db9f1_row7_col5, #T_db9f1_row7_col6, #T_db9f1_row8_col0, #T_db9f1_row8_col1, #T_db9f1_row8_col2, #T_db9f1_row8_col3, #T_db9f1_row8_col4, #T_db9f1_row8_col5, #T_db9f1_row8_col6, #T_db9f1_row9_col0, #T_db9f1_row9_col1, #T_db9f1_row9_col2, #T_db9f1_row9_col3, #T_db9f1_row9_col4, #T_db9f1_row9_col5, #T_db9f1_row9_col6, #T_db9f1_row10_col0, #T_db9f1_row10_col1, #T_db9f1_row10_col2, #T_db9f1_row10_col3, #T_db9f1_row10_col4, #T_db9f1_row10_col5, #T_db9f1_row10_col6, #T_db9f1_row11_col0, #T_db9f1_row11_col1, #T_db9f1_row11_col2, #T_db9f1_row11_col3, #T_db9f1_row11_col4, #T_db9f1_row11_col5, #T_db9f1_row11_col6, #T_db9f1_row12_col0, #T_db9f1_row12_col1, #T_db9f1_row12_col2, #T_db9f1_row12_col3, #T_db9f1_row12_col4, #T_db9f1_row12_col5, #T_db9f1_row12_col6, #T_db9f1_row13_col0, #T_db9f1_row13_col1, #T_db9f1_row13_col2, #T_db9f1_row13_col3, #T_db9f1_row13_col4, #T_db9f1_row13_col5, #T_db9f1_row13_col6, #T_db9f1_row14_col0, #T_db9f1_row14_col1, #T_db9f1_row14_col2, #T_db9f1_row14_col3, #T_db9f1_row14_col4, #T_db9f1_row14_col5, #T_db9f1_row14_col6, #T_db9f1_row15_col0, #T_db9f1_row15_col1, #T_db9f1_row15_col2, #T_db9f1_row15_col3, #T_db9f1_row15_col4, #T_db9f1_row15_col5, #T_db9f1_row15_col6, #T_db9f1_row16_col0, #T_db9f1_row16_col1, #T_db9f1_row16_col2, #T_db9f1_row16_col3, #T_db9f1_row16_col4, #T_db9f1_row16_col5, #T_db9f1_row16_col6, #T_db9f1_row17_col0, #T_db9f1_row17_col1, #T_db9f1_row17_col2, #T_db9f1_row17_col3, #T_db9f1_row17_col4, #T_db9f1_row17_col5, #T_db9f1_row17_col6 {
#   text-align: left;
# }
# #T_db9f1_row0_col1, #T_db9f1_row0_col2, #T_db9f1_row0_col3, #T_db9f1_row0_col4, #T_db9f1_row0_col5, #T_db9f1_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_db9f1_row0_col7, #T_db9f1_row1_col7, #T_db9f1_row2_col7, #T_db9f1_row3_col7, #T_db9f1_row4_col7, #T_db9f1_row5_col7, #T_db9f1_row7_col7, #T_db9f1_row8_col7, #T_db9f1_row9_col7, #T_db9f1_row10_col7, #T_db9f1_row11_col7, #T_db9f1_row12_col7, #T_db9f1_row13_col7, #T_db9f1_row14_col7, #T_db9f1_row15_col7, #T_db9f1_row16_col7, #T_db9f1_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_db9f1_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_db9f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db9f1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_db9f1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_db9f1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_db9f1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_db9f1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_db9f1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_db9f1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_db9f1_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db9f1_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_db9f1_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_db9f1_row0_col1" class="data row0 col1" >694008.0582</td>
#       <td id="T_db9f1_row0_col2" class="data row0 col2" >876617144184.7610</td>
#       <td id="T_db9f1_row0_col3" class="data row0 col3" >914741.1116</td>
#       <td id="T_db9f1_row0_col4" class="data row0 col4" >0.4694</td>
#       <td id="T_db9f1_row0_col5" class="data row0 col5" >0.2139</td>
#       <td id="T_db9f1_row0_col6" class="data row0 col6" >0.1705</td>
#       <td id="T_db9f1_row0_col7" class="data row0 col7" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_db9f1_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_db9f1_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_db9f1_row1_col1" class="data row1 col1" >723904.6824</td>
#       <td id="T_db9f1_row1_col2" class="data row1 col2" >936810774652.2634</td>
#       <td id="T_db9f1_row1_col3" class="data row1 col3" >948205.8825</td>
#       <td id="T_db9f1_row1_col4" class="data row1 col4" >0.4384</td>
#       <td id="T_db9f1_row1_col5" class="data row1 col5" >0.2211</td>
#       <td id="T_db9f1_row1_col6" class="data row1 col6" >0.1781</td>
#       <td id="T_db9f1_row1_col7" class="data row1 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_db9f1_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_db9f1_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_db9f1_row2_col1" class="data row2 col1" >711873.0497</td>
#       <td id="T_db9f1_row2_col2" class="data row2 col2" >986456451646.0367</td>
#       <td id="T_db9f1_row2_col3" class="data row2 col3" >969398.9624</td>
#       <td id="T_db9f1_row2_col4" class="data row2 col4" >0.4099</td>
#       <td id="T_db9f1_row2_col5" class="data row2 col5" >0.2231</td>
#       <td id="T_db9f1_row2_col6" class="data row2 col6" >0.1702</td>
#       <td id="T_db9f1_row2_col7" class="data row2 col7" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_db9f1_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_db9f1_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_db9f1_row3_col1" class="data row3 col1" >710190.9280</td>
#       <td id="T_db9f1_row3_col2" class="data row3 col2" >984114975362.1967</td>
#       <td id="T_db9f1_row3_col3" class="data row3 col3" >967283.2539</td>
#       <td id="T_db9f1_row3_col4" class="data row3 col4" >0.4090</td>
#       <td id="T_db9f1_row3_col5" class="data row3 col5" >0.2241</td>
#       <td id="T_db9f1_row3_col6" class="data row3 col6" >0.1710</td>
#       <td id="T_db9f1_row3_col7" class="data row3 col7" >0.0550</td>
#     </tr>
#     <tr>
#       <th id="T_db9f1_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_db9f1_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_db9f1_row4_col1" class="data row4 col1" >822978.7581</td>
#       <td id="T_db9f1_row4_col2" class="data row4 col2" >1152475172580.9583</td>
#       <td id="T_db9f1_row4_col3" class="data row4 col3" >1050460.1418</td>
#       <td id="T_db9f1_row4_col4" class="data row4 col4" >0.3151</td>
#       <td id="T_db9f1_row4_col5" class="data row4 col5" >0.2466</td>
#       <td id="T_db9f1_row4_col6" class="data row4 col6" >0.2043</td>
#       <td id="T_db9f1_row4_col7" class="data row4 col7" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_db9f1_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_db9f1_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_db9f1_row5_col1" class="data row5 col1" >823803.5039</td>
#       <td id="T_db9f1_row5_col2" class="data row5 col2" >1246843693216.9771</td>
#       <td id="T_db9f1_row5_col3" class="data row5 col3" >1104147.6612</td>
#       <td id="T_db9f1_row5_col4" class="data row5 col4" >0.2460</td>
#       <td id="T_db9f1_row5_col5" class="data row5 col5" >0.2636</td>
#       <td id="T_db9f1_row5_col6" class="data row5 col6" >
