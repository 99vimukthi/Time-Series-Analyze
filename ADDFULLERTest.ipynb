# %% [markdown]
# ## NuwaraEliya Addfuller Test

# %%
# import python pandas package
import pandas as pd

# import the adfuller function from statsmodel 
# package to perform ADF test
from statsmodels.tsa.stattools import adfuller

# read the dataset using pandas read_csv() function
data = pd.read_csv("NuwaraEliyaArima.csv", parse_dates=['Month'],index_col=['Month'])

# extracting only the count using values function
values = data.values

# passing the extracted production count to adfuller function.
# result of adfuller function is stored in a res variable
res = adfuller(values)

# Printing the statistical result of the adfuller test
print('Augmneted Dickey_fuller Statistic: %f' % res[0])
print('p-value: %f' % res[1])

# printing the critical values at different alpha levels.
print('critical values at different levels:')
for k, v in res[4].items():
	print('\t%s: %.3f' % (k, v))
# Out:
# Augmneted Dickey_fuller Statistic: -6.003354
# p-value: 0.000000
# critical values at different levels:
# 	1%: -3.514
# 	5%: -2.898
# 	10%: -2.586

# %% [markdown]
# ## Log Function

# %%
# import python pandas library
import pandas as pd

# import python matplotlib library for plotting
import matplotlib.pyplot as plt

# import python numpy library
import numpy as np

# read the dataset using pandas read_csv()
# function
data = pd.read_csv("NuwaraEliyaArima.csv", parse_dates=['Month'],index_col=['Month'])

# extracting only the  count 
# from the dataset using values function
values = np.log(data.values)

# printing the first 15  count values
print(values[0:15])

# using simple line plot to understand the 
# data distribution
plt.plot(values)
# Out:
# [[15.55374846]
#  [15.44480012]
#  [15.32126166]
#  [15.64287459]
#  [15.85794794]
#  [15.2915117 ]
#  [15.29725054]
#  [15.14720617]
#  [15.02155052]
#  [15.07111377]
#  [15.64470357]
#  [15.49476628]
#  [15.25708186]
#  [15.08216713]
#  [15.46400263]]

# %% [markdown]
# ## Galle Addfuller Test

# %%
# import python pandas package
import pandas as pd

# import the adfuller function from statsmodel 
# package to perform ADF test
from statsmodels.tsa.stattools import adfuller

# read the dataset using pandas read_csv() function
data = pd.read_csv("Galle_Arima_model.csv", parse_dates=['Month'],index_col=['Month'])

# extracting only the  count using values function
values = data.values

# passing the extracted  count to adfuller function.
# result of adfuller function is stored in a res variable
res = adfuller(values)

# Printing the statistical result of the adfuller test
print('Augmneted Dickey_fuller Statistic: %f' % res[0])
print('p-value: %f' % res[1])

# printing the critical values at different alpha levels.
print('critical values at different levels:')
for k, v in res[4].items():
	print('\t%s: %.3f' % (k, v))
# Out:
# Augmneted Dickey_fuller Statistic: -3.788360
# p-value: 0.003029
# critical values at different levels:
# 	1%: -3.513
# 	5%: -2.897
# 	10%: -2.586

# %%
values = np.log(data.values)

# printing the first 15  count values
print(values[0:15])

# using simple line plot to understand the 
# data distribution
plt.plot(values)
# Out:
# [[15.11974011]
#  [14.98746655]
#  [14.97679776]
#  [15.0304693 ]
#  [15.18058358]
#  [15.1350442 ]
#  [14.95537163]
#  [15.14860006]
#  [15.02472042]
#  [14.96561001]
#  [15.27600707]
#  [15.18357221]
#  [14.98941645]
#  [14.85145458]
#  [15.06597002]]

# %% [markdown]
# ## Rathnapura Addfuller Test

# %%
# import python pandas package
import pandas as pd

# import the adfuller function from statsmodel 
# package to perform ADF test
from statsmodels.tsa.stattools import adfuller

# read the dataset using pandas read_csv() function
data = pd.read_csv("Arima_Rathnapura.csv", parse_dates=['Month'],index_col=['Month'])

# extracting only the  count using values function
values = data.values

# passing the extracted  count to adfuller function.
# result of adfuller function is stored in a res variable
res = adfuller(values)

# Printing the statistical result of the adfuller test
print('Augmneted Dickey_fuller Statistic: %f' % res[0])
print('p-value: %f' % res[1])

# printing the critical values at different alpha levels.
print('critical values at different levels:')
for k, v in res[4].items():
	print('\t%s: %.3f' % (k, v))
# Out:
# Augmneted Dickey_fuller Statistic: -2.520015
# p-value: 0.110680
# critical values at different levels:
# 	1%: -3.517
# 	5%: -2.899
# 	10%: -2.587

# %%
values = np.log(data.values)

# printing the first 15  count values
print(values[0:15])

# using simple line plot to understand the 
# data distribution
plt.plot(values)
# Out:
# [[15.62613823]
#  [15.51151985]
#  [15.50644698]
#  [15.66922051]
#  [15.69529708]
#  [15.6330518 ]
#  [15.45488138]
#  [15.58963477]
#  [15.27444902]
#  [15.3521941 ]
#  [15.63688935]
#  [15.56229742]
#  [15.41776835]
#  [15.20349324]
#  [15.64665835]]

# %% [markdown]
# ## Matara Addfuller Test

# %%
# import python pandas package
import pandas as pd

# import the adfuller function from statsmodel 
# package to perform ADF test
from statsmodels.tsa.stattools import adfuller

# read the dataset using pandas read_csv() function
data = pd.read_csv("MataraArima1.csv", parse_dates=['Month'],index_col=['Month'])

# extracting only the  count using values function
values = data.values

# passing the extracted  count to adfuller function.
# result of adfuller function is stored in a res variable
res = adfuller(values)

# Printing the statistical result of the adfuller test
print('Augmneted Dickey_fuller Statistic: %f' % res[0])
print('p-value: %f' % res[1])

# printing the critical values at different alpha levels.
print('critical values at different levels:')
for k, v in res[4].items():
	print('\t%s: %.3f' % (k, v))
# Out:
# Augmneted Dickey_fuller Statistic: -2.315738
# p-value: 0.166942
# critical values at different levels:
# 	1%: -3.517
# 	5%: -2.899
# 	10%: -2.587

# %%
values = np.log(data.values)

# printing the first 15  count values
print(values[0:15])

# using simple line plot to understand the 
# data distribution
plt.plot(values)
# Out:
# [[14.94784868]
#  [14.85325013]
#  [14.50390396]
#  [14.86203485]
#  [14.98166062]
#  [14.99681343]
#  [14.71531737]
#  [14.85150284]
#  [14.71570361]
#  [14.61113129]
#  [15.10829282]
#  [15.02585264]
#  [14.97099361]
#  [14.74626262]
#  [14.83079341]]
