# %%
import pandas as pd

# %%
df=pd.read_csv('AllDistrict_Production_Cleaned_mean.csv')

# %%
df.head()
# Out:
#       Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 0  1/1/2016      3102903.0             0.0               0          219.00
# 1  2/1/2016      2822829.0             8.0               2          201.50
# 2  6/1/2016      3258617.0            68.0              12          172.80
# 3  7/1/2016      2459128.0            79.4               8          215.30
# 4  8/1/2016      2817901.0            34.2               8          220.46
#
#     Fertilizer  District
# 0   160.650000         1
# 1   231.250000         1
# 2   682.300000         1
# 3  1636.673302         1
# 4  1636.673302         1

# %%
df.tail()
# Out:
#          Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 245   8/1/2022      3003573.0           184.4              14      175.528232
# 246   9/1/2022      2957228.0            74.6              15      175.528232
# 247  10/1/2022      2737942.0           749.9              25      175.528232
# 248  11/1/2022      3213092.0           162.3              14      175.528232
# 249  12/1/2022      2986014.0           190.4              13      175.528232
#
#      Fertilizer  District
# 245     1463.90         4
# 246     1325.81         4
# 247     1581.84         4
# 248     1557.84         4
# 249     2200.69         4

# %%
df.shape
# Out:
# (250, 7)

# %%
import numpy as np

# %%
data_train=df.sample(frac=0.9,random_state=786)

# %%
data_train.shape
# Out:
# (225, 7)

# %%
data_train.head()
# Out:
#          Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 162  12/1/2020      6235840.0           203.2              19      175.528232
# 186   2/1/2016      3228301.0           250.1              10      175.528232
# 143  11/1/2018      4340782.0           179.2              16      175.528232
# 55    4/1/2022      2477439.0           156.2               9      198.000000
# 231   2/1/2021      3227056.0            15.4               5      207.000000
#
#       Fertilizer  District
# 162  2641.120000         3
# 186   191.450000         4
# 143  1636.673302         3
# 55    471.860000         1
# 231  3243.770000         4

# %%
data_test=df.drop(data_train.index)

# %%
data_test.shape
# Out:
# (25, 7)

# %%
data_test.head()
# Out:
#         Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 5    1/1/2017      3175557.0            79.1               7      175.528232
# 20   4/1/2018      2946013.0            27.6               4      194.700000
# 23   8/1/2018      2721844.0            76.4              10      175.528232
# 30   4/1/2019      2812379.0           125.3               7      178.500000
# 52  12/1/2021      2312735.0           161.1              11      175.528232
#
#      Fertilizer  District
# 5   1716.020000         1
# 20   523.820000         1
# 23  1987.210000         1
# 30  1636.673302         1
# 52  1532.130000         1

# %%
data_train.reset_index(drop=True,inplace=True)

# %%
data_train.head()
# Out:
#        Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 0  12/1/2020      6235840.0           203.2              19      175.528232
# 1   2/1/2016      3228301.0           250.1              10      175.528232
# 2  11/1/2018      4340782.0           179.2              16      175.528232
# 3   4/1/2022      2477439.0           156.2               9      198.000000
# 4   2/1/2021      3227056.0            15.4               5      207.000000
#
#     Fertilizer  District
# 0  2641.120000         3
# 1   191.450000         4
# 2  1636.673302         3
# 3   471.860000         1
# 4  3243.770000         4

# %%
data_test.reset_index(drop=True,inplace=True)

# %%
data_test.head()
# Out:
#        Month  Production/kg  Rainfall in mm  Rainy days nos  Sunshine hours  \
# 0   1/1/2017      3175557.0            79.1               7      175.528232
# 1   4/1/2018      2946013.0            27.6               4      194.700000
# 2   8/1/2018      2721844.0            76.4              10      175.528232
# 3   4/1/2019      2812379.0           125.3               7      178.500000
# 4  12/1/2021      2312735.0           161.1              11      175.528232
#
#     Fertilizer  District
# 0  1716.020000         1
# 1   523.820000         1
# 2  1987.210000         1
# 3  1636.673302         1
# 4  1532.130000         1

# %%
from pycaret.regression import *

# %%
reg=setup(data=data_train,target="Production/kg",session_id=123)
# Out:
# <style type="text/css">
# #T_d9b74_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d9b74">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9b74_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d9b74_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9b74_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9b74_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d9b74_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9b74_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d9b74_row1_col1" class="data row1 col1" >Production/kg</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9b74_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d9b74_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9b74_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d9b74_row3_col1" class="data row3 col1" >(225, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9b74_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d9b74_row4_col1" class="data row4 col1" >(225, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9b74_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d9b74_row5_col1" class="data row5 col1" >(157, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9b74_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d9b74_row6_col1" class="data row6 col1" >(68, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9b74_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d9b74_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d9b74_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_d9b74_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d9b74_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_d9b74_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d9b74_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_d9b74_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d9b74_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_d9b74_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d9b74_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_d9b74_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d9b74_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_d9b74_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d9b74_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_d9b74_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d9b74_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_d9b74_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d9b74_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_d9b74_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d9b74_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_d9b74_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d9b74_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_d9b74_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d9b74_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_d9b74_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d9b74_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_d9b74_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d9b74_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d9b74_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_d9b74_row21_col1" class="data row21 col1" >752d</td>
#     </tr>
#   </tbody>
# </table>

# %%
best=compare_models(exclude=["ransac"])
# Out:
# <style type="text/css">
# #T_1a74f th {
#   text-align: left;
# }
# #T_1a74f_row0_col0, #T_1a74f_row1_col0, #T_1a74f_row1_col1, #T_1a74f_row1_col2, #T_1a74f_row1_col3, #T_1a74f_row1_col4, #T_1a74f_row1_col5, #T_1a74f_row1_col6, #T_1a74f_row2_col0, #T_1a74f_row2_col1, #T_1a74f_row2_col2, #T_1a74f_row2_col3, #T_1a74f_row2_col4, #T_1a74f_row2_col5, #T_1a74f_row2_col6, #T_1a74f_row3_col0, #T_1a74f_row3_col1, #T_1a74f_row3_col2, #T_1a74f_row3_col3, #T_1a74f_row3_col4, #T_1a74f_row3_col5, #T_1a74f_row3_col6, #T_1a74f_row4_col0, #T_1a74f_row4_col1, #T_1a74f_row4_col2, #T_1a74f_row4_col3, #T_1a74f_row4_col4, #T_1a74f_row4_col5, #T_1a74f_row4_col6, #T_1a74f_row5_col0, #T_1a74f_row5_col1, #T_1a74f_row5_col2, #T_1a74f_row5_col3, #T_1a74f_row5_col4, #T_1a74f_row5_col5, #T_1a74f_row5_col6, #T_1a74f_row6_col0, #T_1a74f_row6_col1, #T_1a74f_row6_col2, #T_1a74f_row6_col3, #T_1a74f_row6_col4, #T_1a74f_row6_col5, #T_1a74f_row6_col6, #T_1a74f_row7_col0, #T_1a74f_row7_col1, #T_1a74f_row7_col2, #T_1a74f_row7_col3, #T_1a74f_row7_col4, #T_1a74f_row7_col5, #T_1a74f_row7_col6, #T_1a74f_row8_col0, #T_1a74f_row8_col1, #T_1a74f_row8_col2, #T_1a74f_row8_col3, #T_1a74f_row8_col4, #T_1a74f_row8_col5, #T_1a74f_row8_col6, #T_1a74f_row9_col0, #T_1a74f_row9_col1, #T_1a74f_row9_col2, #T_1a74f_row9_col3, #T_1a74f_row9_col4, #T_1a74f_row9_col5, #T_1a74f_row9_col6, #T_1a74f_row10_col0, #T_1a74f_row10_col1, #T_1a74f_row10_col2, #T_1a74f_row10_col3, #T_1a74f_row10_col4, #T_1a74f_row10_col5, #T_1a74f_row10_col6, #T_1a74f_row11_col0, #T_1a74f_row11_col1, #T_1a74f_row11_col2, #T_1a74f_row11_col3, #T_1a74f_row11_col4, #T_1a74f_row11_col5, #T_1a74f_row11_col6, #T_1a74f_row12_col0, #T_1a74f_row12_col1, #T_1a74f_row12_col2, #T_1a74f_row12_col3, #T_1a74f_row12_col4, #T_1a74f_row12_col5, #T_1a74f_row12_col6, #T_1a74f_row13_col0, #T_1a74f_row13_col1, #T_1a74f_row13_col2, #T_1a74f_row13_col3, #T_1a74f_row13_col4, #T_1a74f_row13_col5, #T_1a74f_row13_col6, #T_1a74f_row14_col0, #T_1a74f_row14_col1, #T_1a74f_row14_col2, #T_1a74f_row14_col3, #T_1a74f_row14_col4, #T_1a74f_row14_col5, #T_1a74f_row14_col6, #T_1a74f_row15_col0, #T_1a74f_row15_col1, #T_1a74f_row15_col2, #T_1a74f_row15_col3, #T_1a74f_row15_col4, #T_1a74f_row15_col5, #T_1a74f_row15_col6, #T_1a74f_row16_col0, #T_1a74f_row16_col1, #T_1a74f_row16_col2, #T_1a74f_row16_col3, #T_1a74f_row16_col4, #T_1a74f_row16_col5, #T_1a74f_row16_col6, #T_1a74f_row17_col0, #T_1a74f_row17_col1, #T_1a74f_row17_col2, #T_1a74f_row17_col3, #T_1a74f_row17_col4, #T_1a74f_row17_col5, #T_1a74f_row17_col6 {
#   text-align: left;
# }
# #T_1a74f_row0_col1, #T_1a74f_row0_col2, #T_1a74f_row0_col3, #T_1a74f_row0_col4, #T_1a74f_row0_col5, #T_1a74f_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1a74f_row0_col7, #T_1a74f_row1_col7, #T_1a74f_row2_col7, #T_1a74f_row3_col7, #T_1a74f_row4_col7, #T_1a74f_row5_col7, #T_1a74f_row7_col7, #T_1a74f_row8_col7, #T_1a74f_row9_col7, #T_1a74f_row10_col7, #T_1a74f_row11_col7, #T_1a74f_row12_col7, #T_1a74f_row13_col7, #T_1a74f_row14_col7, #T_1a74f_row16_col7, #T_1a74f_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1a74f_row6_col7, #T_1a74f_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1a74f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a74f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1a74f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1a74f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1a74f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1a74f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1a74f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1a74f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1a74f_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a74f_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_1a74f_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1a74f_row0_col1" class="data row0 col1" >625825.8681</td>
#       <td id="T_1a74f_row0_col2" class="data row0 col2" >675236365439.1473</td>
#       <td id="T_1a74f_row0_col3" class="data row0 col3" >803266.9962</td>
#       <td id="T_1a74f_row0_col4" class="data row0 col4" >0.4897</td>
#       <td id="T_1a74f_row0_col5" class="data row0 col5" >0.1870</td>
#       <td id="T_1a74f_row0_col6" class="data row0 col6" >0.1514</td>
#       <td id="T_1a74f_row0_col7" class="data row0 col7" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_1a74f_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_1a74f_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_1a74f_row1_col1" class="data row1 col1" >653359.2537</td>
#       <td id="T_1a74f_row1_col2" class="data row1 col2" >731591287877.6818</td>
#       <td id="T_1a74f_row1_col3" class="data row1 col3" >836218.3908</td>
#       <td id="T_1a74f_row1_col4" class="data row1 col4" >0.4518</td>
#       <td id="T_1a74f_row1_col5" class="data row1 col5" >0.1954</td>
#       <td id="T_1a74f_row1_col6" class="data row1 col6" >0.1594</td>
#       <td id="T_1a74f_row1_col7" class="data row1 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_1a74f_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_1a74f_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_1a74f_row2_col1" class="data row2 col1" >656312.8157</td>
#       <td id="T_1a74f_row2_col2" class="data row2 col2" >750352987837.5414</td>
#       <td id="T_1a74f_row2_col3" class="data row2 col3" >844151.5865</td>
#       <td id="T_1a74f_row2_col4" class="data row2 col4" >0.4422</td>
#       <td id="T_1a74f_row2_col5" class="data row2 col5" >0.1954</td>
#       <td id="T_1a74f_row2_col6" class="data row2 col6" >0.1594</td>
#       <td id="T_1a74f_row2_col7" class="data row2 col7" >0.0430</td>
#     </tr>
#     <tr>
#       <th id="T_1a74f_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_1a74f_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_1a74f_row3_col1" class="data row3 col1" >687690.8746</td>
#       <td id="T_1a74f_row3_col2" class="data row3 col2" >821732268866.9141</td>
#       <td id="T_1a74f_row3_col3" class="data row3 col3" >884784.6852</td>
#       <td id="T_1a74f_row3_col4" class="data row3 col4" >0.3799</td>
#       <td id="T_1a74f_row3_col5" class="data row3 col5" >0.2065</td>
#       <td id="T_1a74f_row3_col6" class="data row3 col6" >0.1665</td>
#       <td id="T_1a74f_row3_col7" class="data row3 col7" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_1a74f_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_1a74f_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_1a74f_row4_col1" class="data row4 col1" >713770.9196</td>
#       <td id="T_1a74f_row4_col2" class="data row4 col2" >903935944807.2026</td>
#       <td id="T_1a74f_row4_col3" class="data row4 col3" >923356.3051</td>
#       <td id="T_1a74f_row4_col4" class="data row4 col4" >0.3303</td>
#       <td id="T_1a74f_row4_col5" class="data row4 col5" >0.2127</td>
#       <td id="T_1a74f_row4_col6" class="data row4 col6" >0.1750</td>
#       <td id="T_1a74f_row4_col7" class="data row4 col7" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_1a74f_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_1a74f_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_1a74f_row5_col1" class="data row5 col1" >691634.1044</td>
#       <td id="T_1a74f_row5_col2" class="data row5 col2" >905617412232.1285</td>
#       <td id="T_1a74f_row5_col3" class="data row5 col3" >920278.2074</td>
#       <td id="T_1a74f_row5_col4" class="data row5 col4" >0.2957</td>
#       <td id="T_1a74f_row5_col5" class="data row5 col5" >0.2195</td>
#       <td id="T_1a74f_row5_col6" class="data row5 col6" >0.16
